# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Series

Country = pd.Series(['Brazil', 'Rusia','India', 'China']) #Creating a series

print(Bric) #Notice that a series has an index
# Out:
# 0    Brazil
# 1     Rusia
# 2     India
# 3     China
# dtype: object

# %%
#Data frame

GDP = pd.Series ([2194, 2554, 2848, 12630])
Pop = pd.Series([209, 147, 1352, 1390]) 
Cap = ('Brasilia', 'Moscow', 'New Delhi', 'Beijing')

Bric = pd.DataFrame({'Country': Country, 'GDP': GDP, 'Population':Pop, 'Capital': Capital})

print(Bric)

Bric = Bric.set_index('Country') #Data frame index

print('\n',Bric)
# Out:
#   Country    GDP  Population    Capital
# 0  Brazil   2194         209   Brasilia
# 1   Rusia   2554         147     Moscow
# 2   India   2848        1352  New Delhi
# 3   China  12630        1390    Beijing
#
#             GDP  Population    Capital
# Country
# Brazil    2194         209   Brasilia
# Rusia     2554         147     Moscow
# India     2848        1352  New Delhi
# China    12630        1390    Beijing

# %%
#Lets import a large data set

Games = pd.read_csv('https://www.dataquest.io/wp-content/uploads/2019/09/ign.csv')

m, n = Games.shape
print('Games has:', m,'rows and', n, 'columns')
# Out:
# Games has: 18625 rows and 11 columns

# %%
#Visualizing top 5

Games.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
#Slicing

Games.iloc[:,:] # Try 5:7, 6:10, etc.
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# 5               5         Good
# 6               6        Awful
# 7               7      Amazing
# 8               8        Awful
# 9               9         Good
# 10             10         Good
# 11             11         Good
# 12             12         Good
# 13             13      Amazing
# 14             14      Amazing
# 15             15         Okay
# 16             16         Okay
# 17             17        Great
# 18             18     Mediocre
# 19             19         Good
# 20             20         Good
# 21             21         Good
# 22             22         Good
# 23             23         Good
# 24             24      Amazing
# 25             25         Good
# 26             26      Amazing
# 27             27         Good
# 28             28        Great
# ...

# %%
# Let's get rid of the first columm #Do not run twice

#Games = Games.iloc[:,1:]
Games.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# ...

# %%
#Slice and copy

Few = Games.iloc[10:20,:] # Try 5:7, 6:10, etc.
Few.head()
# Out:
#    score_phrase                    title  \
# 10         Good  Tekken Tag Tournament 2
# 11         Good  Tekken Tag Tournament 2
# 12         Good               Wild Blood
# 13      Amazing        Mark of the Ninja
# 14      Amazing        Mark of the Ninja
#
#                                                 url       platform  score  \
# 10        /games/tekken-tag-tournament-2/ps3-124584  PlayStation 3    7.5
# 11   /games/tekken-tag-tournament-2/xbox-360-124581       Xbox 360    7.5
# 12                  /games/wild-blood/iphone-139363         iPhone    7.0
# 13  /games/mark-of-the-ninja-135615/xbox-360-129276       Xbox 360    9.0
# 14        /games/mark-of-the-ninja-135615/pc-143761             PC    9.0
#
#                 genre editors_choice  release_year  release_month  release_day
# 10           Fighting              N          2012              9           11
# 11           Fighting              N          2012              9           11
# ...

# %%
#Finding values by indexes and row names

#Few.loc[10:15,:] #Row names
Few.iloc[0:4,:]   #Indeces
# Out:
#    score_phrase                    title  \
# 10         Good  Tekken Tag Tournament 2
# 11         Good  Tekken Tag Tournament 2
# 12         Good               Wild Blood
# 13      Amazing        Mark of the Ninja
#
#                                                 url       platform  score  \
# 10        /games/tekken-tag-tournament-2/ps3-124584  PlayStation 3    7.5
# 11   /games/tekken-tag-tournament-2/xbox-360-124581       Xbox 360    7.5
# 12                  /games/wild-blood/iphone-139363         iPhone    7.0
# 13  /games/mark-of-the-ninja-135615/xbox-360-129276       Xbox 360    9.0
#
#                 genre editors_choice  release_year  release_month  release_day
# 10           Fighting              N          2012              9           11
# 11           Fighting              N          2012              9           11
# 12                NaN              N          2012              9           10
# ...

# %%
# Calling using column names

Games.loc[1000:1005, ['title','score', 'score_phrase']]
# Out:
#                                  title  score score_phrase
# 1000  Twisted Edge Extreme Snowboading    6.8         Okay
# 1001                         Fallout 2    8.9        Great
# 1002                         Asteroids    6.0         Okay
# 1003                   Twisted Metal 3    4.0          Bad
# 1004        Rush 2: Extreme Racing USA    8.9        Great
# 1005                    Small Soldiers    7.2         Good

# %%
#Retrive a column

Games['score']
# Out:
# 0         9.0
# 1         9.0
# 2         8.5
# 3         8.5
# 4         8.5
# 5         7.0
# 6         3.0
# 7         9.0
# 8         3.0
# 9         7.0
# 10        7.5
# 11        7.5
# 12        7.0
# 13        9.0
# 14        9.0
# 15        6.5
# 16        6.5
# 17        8.0
# 18        5.5
# 19        7.0
# 20        7.0
# 21        7.5
# 22        7.5
# 23        7.5
# 24        9.0
# 25        7.0
# 26        9.0
# 27        7.5
# 28        8.0
# 29        6.5
#          ...
# 18595     4.4
# 18596     6.5
# 18597     4.9
# 18598     6.8
# 18599     7.0
# 18600     7.4
# 18601     7.4
# 18602     7.4
# 18603     7.8
# 18604     8.6
# 18605     6.0
# 18606     6.4
# 18607     7.0
# 18608     5.4
# 18609     8.0
# 18610     6.0
# 18611     5.8
# 18612     7.8
# 18613     8.0
# 18614     9.2
# 18615     9.2
# 18616     7.5
# 18617     8.4
# 18618     9.1
# 18619     7.9
# 18620     7.6
# 18621     9.0
# 18622     5.8
# 18623    10.0
# 18624    10.0
# ...

# %%
#Call many columns
Few[['score', 'release_year']]
# Out:
#     score  release_year
# 10    7.5          2012
# 11    7.5          2012
# 12    7.0          2012
# 13    9.0          2012
# 14    9.0          2012
# 15    6.5          2012
# 16    6.5          2012
# 17    8.0          2012
# 18    5.5          2012
# 19    7.0          2012

# %%
type(Games['release_year'])
# Out:
# pandas.core.series.Series

# %%
#Series with multiple data types
a = pd.Series(['a', 8, False])
a
# Out:
# 0        a
# 1        8
# 2    False
# dtype: object

# %%
#Series with other objects
r = pd.Series([a, Bric, 8, 'Hello'])
r
# Out:
# 0       0        a
# 1        8
# 2    False
# dtype: object
# 1               GDP  Population    Capital
# Country ...
# 2                                                    8
# 3                                                Hello
# dtype: object

# %%
#Methods

print(Games['score'].mean()) #Mean of one column

print(Games.mean()) #All possible means
# Out:
# 6.950459060402666
# score               6.950459
# release_year     2006.515329
# release_month       7.138470
# release_day        15.603866
# dtype: float64

# %%
#Methods

Games.mean(axis = 1) #Mean of each row (axis 0 is columns) np is the other way!!
# Out:
# 0        510.500
# 1        510.500
# 2        510.375
# 3        510.125
# 4        510.125
# 5        509.750
# 6        508.750
# 7        510.250
# 8        508.750
# 9        509.750
# 10       509.875
# 11       509.875
# 12       509.500
# 13       509.250
# 14       509.250
# 15       508.375
# 16       508.375
# 17       508.500
# 18       507.375
# 19       507.750
# 20       507.750
# 21       514.625
# 22       514.625
# 23       514.625
# 24       515.000
# 25       514.250
# 26       514.750
# 27       514.125
# 28       514.250
# 29       513.625
#           ...
# 18595    510.850
# 18596    510.875
# 18597    510.225
# 18598    510.700
# 18599    510.750
# 18600    512.600
# 18601    512.600
# 18602    512.600
# 18603    512.450
# 18604    512.400
# 18605    511.500
# 18606    508.600
# 18607    510.750
# 18608    510.350
# 18609    510.750
# 18610    510.250
# 18611    508.700
# 18612    509.200
# 18613    508.000
# 18614    515.050
# 18615    515.050
# ...

# %%
#Method counting

Games.count() #Counts the number of non-null values in each DataFrame column.
# Out:
# score_phrase      18625
# title             18625
# url               18625
# platform          18625
# score             18625
# genre             18589
# editors_choice    18625
# release_year      18625
# release_month     18625
# release_day       18625
# dtype: int64

# %%
#Games.max()    #Finds the highest value in each column.
#Games.min()    #Finds the lowest value in each column.
#Games.median() #Finds the median of each column.
#Games.std()    #Finds the standard deviation of each column.
Games.corr() #Dinds the correlation between columns in a DataFrame.
# Out:
#                   score  release_year  release_month  release_day
# score          1.000000      0.062716       0.007632     0.020079
# release_year   0.062716      1.000000      -0.115515     0.016867
# release_month  0.007632     -0.115515       1.000000    -0.067964
# release_day    0.020079      0.016867      -0.067964     1.000000

# %%
#Other functions
# Out:
#                   score  release_year  release_month  release_day
# score          1.000000      0.062716       0.007632     0.020079
# release_year   0.062716      1.000000      -0.115515     0.016867
# release_month  0.007632     -0.115515       1.000000    -0.067964
# release_day    0.020079      0.016867      -0.067964     1.000000

# %%
#Filters

#Games['score']>8

Good = Games['score']>8
Good

Games[Good]
# Out:
#       score_phrase                                              title  \
# 0          Amazing                            LittleBigPlanet PS Vita
# 1          Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2            Great                               Splice: Tree of Life
# 3            Great                                             NHL 13
# 4            Great                                             NHL 13
# 7          Amazing                                       Guild Wars 2
# 13         Amazing                                  Mark of the Ninja
# 14         Amazing                                  Mark of the Ninja
# 24         Amazing                Dark Souls (Prepare to Die Edition)
# 26         Amazing                                            Bastion
# 30         Amazing  The Walking Dead: The Game -- Episode 3: Long ...
# 31           Great               World of Warcraft: Mists of Pandaria
# ...

# %%
Good = (Games['score'] > 8) & (Games["platform"] == 'Xbox One') & (Games['release_year'] == 2016)
Games[Good]
# Out:
#       score_phrase                                 title  \
# 18354  Masterpiece                           The Witness
# 18426      Amazing                             Firewatch
# 18452        Great                               FIFA 17
# 18455      Amazing                       Forza Horizon 3
# 18459        Great              BioShock: The Collection
# 18464      Amazing             Pro Evolution Soccer 2017
# 18468        Great                                NHL 17
# 18482        Great                      TrackMania Turbo
# 18548        Great  Plants vs. Zombies: Garden Warfare 2
# 18556        Great                     Hitman: Episode 2
# 18571      Amazing                             Overwatch
# 18582        Great                                   Fru
# 18588        Great                               F1 2016
# 18591      Amazing              Deus Ex: Mankind Divided
# 18623  Masterpiece                                Inside
#
# ...

# %%
Games['score'].plot(kind="hist", color = 'green')

# %%
#Plots

Games[Games["platform"] == "Xbox One"]["score"].plot(kind="hist")
